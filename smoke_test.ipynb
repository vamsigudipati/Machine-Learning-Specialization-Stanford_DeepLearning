# %%
import sys
import sklearn
print(f"System Green. Python Version: {sys.version}")
print("✅ Stanford Engine: OPERATIONAL")
# Out:
# System Green. Python Version: 3.9.25 (main, Nov  3 2025, 22:29:32)
# [Clang 20.1.8 ]
# ✅ Stanford Engine: OPERATIONAL
